# %% [markdown]
# <a href="https://colab.research.google.com/github/tazeezx/COB-Data-Science/blob/main/Phase1_Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import the dataset using pandas

# %%
data = pd.read_csv("/content/dataset - netflix1.csv")
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %% [markdown]
# Get information about the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %% [markdown]
# Start replacing 'Not Given' values to NaN for easy cleaning

# %%
data['director'] = data['director'].replace('Not Given', np.NaN)
data['country'] = data['country'].replace('Not Given', np.NaN)
data.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# Find the number of rows which have a null value

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2588
# country          287
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# dtype: int64

# %% [markdown]
# Fill those null values with whitespace

# %%
new = data.fillna(" ")
new.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %% [markdown]
# Change the datatype to pandas datetime object in the column of 'date_added'

# %%
new['date_added'] = pd.to_datetime(new['date_added'], errors = 'coerce')
new['date_added'] = new['date_added'].dt.strftime('%d/%m/%y')

# %%
missed_dates = new['date_added'].isnull().sum()

# %%
duration = lambda duration: int(duration) if isinstance(duration, int) else int(''.join(filter(str.isdigit, duration)))
new['duration'] = new['duration'].apply(duration)
new
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre
# 8786   s8798  TV Show                         Zak Storm
# 8787   s8801  TV Show                Zindagi Gulzar Hai
# 8788   s8784  TV Show                              Yoko
# 8789   s8786  TV Show                               YOM
#
#             country date_added  release_year rating  duration  \
# 0     United States   25/09/21          2020  PG-13        90
# ...

# %%
import seaborn as sns
sns.boxplot(x=new['release_year'])
# Out:
# <Axes: xlabel='release_year'>

# %%
sns.histplot(x=new['release_year'], kde=True)
# Out:
# <Axes: xlabel='release_year', ylabel='Count'>

# %%
new['release_year'].describe()
# Out:
# count    8790.000000
# mean     2014.183163
# std         8.825466
# min      1925.000000
# 25%      2013.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
percentile25 = new['release_year'].quantile(0.25)
percentile75 = new['release_year'].quantile(0.75)
percentile25, percentile75
# Out:
# (2013.0, 2019.0)

# %%
IQR = percentile75 - percentile25
IQR
# Out:
# 6.0

# %%
UL = percentile75 + 1.5*IQR
LL = percentile25 - 1.5*IQR
print(UL, '- upper limit')
print(LL, '- lower limit')
# Out:
# 2028.0 - upper limit
# 2004.0 - lower limit

# %%
new[new['release_year'] > UL]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, country, date_added, release_year, rating, duration, listed_in]
# Index: []

# %%
new[new['release_year'] < LL]
# Out:
#      show_id     type                                title          director  \
# 4         s8    Movie                              Sankofa      Haile Gerima
# 29       s25    Movie                                Jeans        S. Shankar
# 51       s27    Movie                       Minsara Kanavu       Rajiv Menon
# 53       s23    Movie                      Avvai Shanmughi    K.S. Ravikumar
# 60       s42    Movie                                 Jaws  Steven Spielberg
# ...      ...      ...                                  ...               ...
# 8702   s8232    Movie                             The Bund
# 8743   s8524  TV Show    The Super Mario Bros. Super Show!
# 8746   s8542  TV Show  The Twilight Zone (Original Series)
# 8761   s8645  TV Show                           Twin Peaks
# 8765   s8670  TV Show                        V.R. Troopers
#
#             country date_added  release_year rating  duration  \
# 4     United States   24/09/21          1993  TV-MA       125
# ...

# %%
data2 = new[new['release_year'] > LL]
data2.shape
# Out:
# (8009, 10)

# %% [markdown]
# Find outliers

# %%
sns.boxplot(x = data2['release_year'])
# Out:
# <Axes: xlabel='release_year'>

# %%
sns.histplot(x = data2['release_year'], kde=True)
# Out:
# <Axes: xlabel='release_year', ylabel='Count'>

# %%
data2['release_year'].describe()
# Out:
# count    8009.000000
# mean     2016.408291
# std         3.637256
# min      2005.000000
# 25%      2015.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
percentile_25 = data2['release_year'].quantile(0.25)
percentile_75 = data2['release_year'].quantile(0.75)
percentile_25, percentile_75
# Out:
# (2015.0, 2019.0)

# %%
IQR_ = percentile_75 - percentile_25
IQR
# Out:
# 6.0

# %%
upper_limit = percentile_75 + 1.5*IQR_
lower_limit = percentile_25 - 1.5*IQR_
print(upper_limit, '- upper limit')
print(lower_limit, '- lower limit')
# Out:
# 2025.0 - upper limit
# 2009.0 - lower limit

# %%
data2[data2['release_year'] > upper_limit]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, country, date_added, release_year, rating, duration, listed_in]
# Index: []

# %%
data2[data2['release_year'] < lower_limit]
# Out:
#      show_id     type                                              title  \
# 82       s58    Movie                  Naruto Shippûden the Movie: Bonds
# 84       s60    Movie                        Naruto Shippuden: The Movie
# 86       s62    Movie   Naruto the Movie 2: Legend of the Stone of Gelel
# 87       s63    Movie  Naruto the Movie 3: Guardians of the Crescent ...
# 181     s130    Movie                                 An Unfinished Life
# ...      ...      ...                                                ...
# 8693   s8175  TV Show                                     That '70s Show
# 8714   s8317  TV Show                                The Future of Water
# 8736   s8477  TV Show                        The Real Football Factories
# 8748   s8552  TV Show       The War: A Film by Ken Burns and Lynn Novick
# 8749   s8558  TV Show                                      The West Wing
#
#                 director         country date_added  release_year rating  \
# ...

# %%
data3 = data2[data2['release_year'] > lower_limit]
data3.shape
# Out:
# (7458, 10)

# %%
sns.boxplot(x=data3['release_year'])
# Out:
# <Axes: xlabel='release_year'>

# %%
data3['release_year'].describe()
# Out:
# count    7458.000000
# mean     2017.078842
# std         2.742873
# min      2010.000000
# 25%      2016.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
upper_limit = 2019.0 + 1.5*3
lower_limit = 2016.0 - 1.5*3
print(upper_limit, ':', lower_limit, '- upper and lower limits')
# Out:
# 2023.5 : 2011.5 - upper and lower limits

# %%
data3[data3['release_year'] < lower_limit]
# Out:
#      show_id     type                                        title  \
# 30       s28    Movie                                    Grown Ups
# 81       s57    Movie     Naruto Shippuden the Movie: Blood Prison
# 85       s61    Movie  Naruto Shippuden: The Movie: The Lost Tower
# 97      s337  TV Show                          Friday Night Lights
# 161     s928  TV Show                           Barney and Friends
# ...      ...      ...                                          ...
# 8724   s8374  TV Show                              The Jungle Book
# 8745   s8540  TV Show                                   The Tudors
# 8750   s8561  TV Show                                The Womanizer
# 8774   s8737  TV Show                                Who's the One
# 8779   s8756  TV Show                            Women Behind Bars
#
#              director        country date_added  release_year rating  \
# 30       Dennis Dugan  United States   20/09/21          2010  PG-13
# ...

# %%
data3 = data2[data2['release_year'] > lower_limit]
data3.shape
# Out:
# (7081, 10)

# %%
sns.boxplot(x=data3['release_year'])
# Out:
# <Axes: xlabel='release_year'>

# %%
sns.histplot(x = data3['release_year'], kde=True)
# Out:
# <Axes: xlabel='release_year', ylabel='Count'>
